# %% [markdown]
# # Laboratorio Práctico: Creando un Paquete de Python
#
# ## Creando un Paquete de Python
#
#
# ## Objetivos
# En este laboratorio usted:
#
# - Creará un módulo llamado basic
# - Agregará dos funciones al módulo basic
# - Creará un módulo llamado stats
# - Agregará dos funciones al módulo stats
# - Creará un paquete de python llamado mymath
# - Verificará que el paquete esté funcionando
#
#
# 1. Archivo y selecciona la opción Nueva Carpeta
# Ingresa mymath y haz clic en Aceptar, como se muestra en la imagen a continuación.
#
#
# Crear el primer módulo
# Crea un módulo de python llamado basic
# Crea un archivo llamado basic.py.
#
# Copia y pega el siguiente código en basic.py.
#
# ```PYTHON
# def square(number):
#     """
#     This function returns the square of a given number
#     """
#     return number ** 2
# def double(number):
#     """
#     This function returns twice the value of a given number
#     """
#     return number * 2
# def add(a, b):
#     """
#     This function returns the sum of given numbers
#     """
#     return a + b
# ```
#
# Guarda el archivo basic.py
#
#
# ## Crear el segundo módulo
# Crea un módulo llamado stats
# Crea un archivo llamado stats.py.
#
# Copia y pega el siguiente código en stats.py.
#
# ```python
# def mean(numbers):
#     """
#     This function returns the mean of the given list of numbers.
#     The mean is calculated as the sum of all numbers divided by the count of numbers.
#     """
#     # Calculate the mean by summing all the numbers and dividing by the length of the list.
#     # 'sum(numbers)' computes the total of all numbers in the list.
#     # 'len(numbers)' gives the count of numbers in the list.
#     # The mean (or average) is the total sum divided by the number of elements.
#     return sum(numbers) / len(numbers)  # Return the mean value.
# def median(numbers):
#     """
#     This function returns the median of the given list of numbers.
#     The median is the middle value when the numbers are sorted.
#     If there is an even number of observations, it returns the average of the two middle numbers.
#     """
#     # Sort the list of numbers in ascending order.
#     # Sorting is necessary to find the median, as the median depends on the order of values.
#     numbers.sort()
#     # Check if the number of elements in the list is even.
#     # len(numbers) % 2 == 0 evaluates to True if the list has an even number of elements.
#     if len(numbers) % 2 == 0:
#         # If the list has an even number of elements, find the two middle numbers.
#         # 'len(numbers) // 2' computes the index of the second middle element in a zero-indexed list.
#         # 'len(numbers) // 2 - 1' computes the index of the first middle element.
#         median1 = numbers[len(numbers) // 2]  # The higher index of the two middle values.
#         median2 = numbers[len(numbers) // 2 - 1]  # The lower index of the two middle values.
#
#         # Calculate the median by taking the average of the two middle numbers.
#         # This is done by adding the two middle values and dividing by 2.
#         mymedian = (median1 + median2) / 2  # Average of the two middle values.
#     else:
#         # If the list has an odd number of elements, return the middle number.
#         # 'len(numbers) // 2' computes the index of the middle element.
#         mymedian = numbers[len(numbers) // 2]  # The middle value for lists with an odd number of elements.
#     # Return the calculated median value.
#     return mymedian
#
# ```
#
# ## Crear init.py
# Crea el archivo <code>__init__.py</code>
# Copia y pega el siguiente código en <code>__init__.py</code>
#
# ```python
# from . import basic
# from . import stats
# ```
# Guarda el archivo __init__.py
#
# Ahora tu estructura de directorios debería verse así
#
# ```python
# mymath
# mymath/__init__.py
# mymath/basic.py
# mymath/statistics.py
# ```
#
# ![image.png](attachment:image.png)
#
# ## Verificar el paquete
# En la ventana de la derecha, haz clic en el menú Terminal y selecciona la opción Nuevo Terminal,
#
# - En el terminal, escribe python3 para invocar el intérprete de Python.
# - Una vez que se cargue el intérprete de Python.
# - En el indicador de Python, escribe import mymath
# - Si el comando anterior se ejecuta sin errores, es una indicación de que el paquete mymath se ha cargado correctamente.
# - En el indicador de Python, escribe mymath.basic.add(3,4)
# - Deberías ver un resultado 7 en la pantalla.
# - En el indicador de Python, escribe mymath.stats.mean([3,4,5])
# - Deberías ver un resultado 4.0 en la pantalla.
# - Escribe exit() para salir del intérprete de Python.
#
# ## Ejercicio Práctico
# Crea un nuevo módulo llamado geometry y añádelo al paquete mymath.
# - Crea un módulo llamado geometry
# - Añade una función llamada area_of_rectangle que tome como entrada la longitud y el ancho y devuelva el área de un rectángulo.
# - Añade una función llamada area_of_circle que tome como entrada el radio y devuelva el área de un círculo.
# - Modifica el __init__.py para incluir este módulo.
# - Importa y prueba la función area_of_circle desde la terminal de Python.
